# %%
import h5py
import numpy as np

# %%
data_path = 'E:\master\\final_project\data\my_data\embedding_output_data\cnn_embedding\\100_400\\fold_1\\train\data.h5'
with h5py.File(data_path, 'r') as f:
    print(f.keys())
# Out:
# <KeysViewHDF5 ['labels', 'vectors']>

# %%
with h5py.File(data_path, 'r') as f:
    print(f['vectors'][:].shape)
    print(f['vectors'][5])
# Out:
# (460632, 64)
# [0.         0.         0.14330202 0.01579413 0.08392236 0.02336751
#  0.         0.19322374 0.0717838  0.         0.         0.
#  0.         0.         0.         0.13891006 0.         0.1724871
#  0.10401166 0.         0.19031161 0.         0.16404557 0.
#  0.00178607 0.         0.         0.         0.159439   0.06597357
#  0.03871268 0.         0.11734666 0.35132962 0.         0.11354052
#  0.         0.08099297 0.2248802  0.         0.         0.15763858
#  0.07994534 0.05479236 0.02379106 0.03532226 0.04188205 0.04605578
#  0.00840287 0.13676158 0.         0.         0.0134683  0.00647702
#  0.         0.17047572 0.         0.         0.         0.05897392
#  0.         0.2142201  0.12619938 0.00848535]
