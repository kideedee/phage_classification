# %%
import numpy as np

# %%
path = "E:\master\\final_project\data\my_data\contig_fix_bug\\100_400\\fold_1\\test\\fcgr_labels.npy"
labels = np.load(path)

# %%
unique_vals, counts = np.unique(labels, return_counts=True)
print("\nMethod 1: np.unique() with return_counts=True")
print("Unique values:", unique_vals)
print("Counts:", counts)
# Out:
# Method 1: np.unique() with return_counts=True
# Unique values: [0 1]
# Counts: [ 57344 215156]
