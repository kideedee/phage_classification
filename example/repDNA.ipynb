# %%
from repDNA.nac import Kmer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from repDNA.nac import Kmer
#
# File ~\miniconda3\envs\dnabert\lib\site-packages\repDNA\nac.py:4
#       1 __author__ = 'Fule Liu'
# ----> 4 from nacutil import make_upto_kmer_list, make_revcomp_kmer_list, make_kmer_vector
#       5 from util import get_data
#       8 def check_nac_para(k, normalize=False, upto=False, alphabet='ACGT'):
#
# ModuleNotFoundError: No module named 'nacutil'
